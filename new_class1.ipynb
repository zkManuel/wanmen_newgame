# %%
import graphviz

# %%
import sklearn.datasets as datasets
import pandas as pd
iris=datasets.load_iris()
df=pd.DataFrame(iris.data, columns=iris.feature_names)
y=iris.target

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
dot_data=StringIO()
export_graphviz(dtree, out_file=dot_data,
                filled=True, rounded=True,
                special_characters=True)
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
import numpy as np
A = np.array([1,2,3])
B = np.array([4,3,0])
print('A+B = ', np.add(A,B))
print('A-B =' , np.subtract(A,B))
# Out:
# A+B =  [5 5 3]
# A-B = [-3 -1  3]

# %%
A=np.array([1,2,3])
print('np.multiply(A,A)=', np.multiply(A,A))
print('A*A=', A*A)

# %%
df wanmen()
    print('hello')

# %%
** 黑体 **
# Out:
#   File "<ipython-input-1-18f5d76c6ba5>", line 1
#     ** 黑体 **
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ** 黑体 **

# %%
*写*
# Out:
#   File "<ipython-input-2-fedcd31e21c9>", line 1
#     *写*
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# *写*

# %% [markdown]
# * 列出

# %%
* **列出**
# Out:
#   File "<ipython-input-3-833bb135297f>", line 1
#     * **列出**
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# * **列出**

# %%
** 大家好**
# Out:
#   File "<ipython-input-4-91bcaf2a53d1>", line 1
#     ** 大家好**
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# **大家好**

# %% [markdown]
# 1. 要有空格
# 2. 序号跟数字没关系
# 4. 好啊

# %% [markdown]
# Latex

# %% [markdown]
# \pi

# %% [markdown]
# $\pi$

# %% [markdown]
# $\sum$

# %% [markdown]
# $\sum_{i=1}^{i=n}&

# %% [markdown]
# $\sum_{i=1}^{i=n}$

# %% [markdown]
# <img src='./spacex.jpg',width=200>

# %%
from IPython.display import Image

# %%
Image(filename='./spacex.jpg',width=200)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-74e89563c1e9> in <module>()
# ----> 1 Image(filename='./spacex.jpg',width=200)
#
# D:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1149         self.unconfined = unconfined
#    1150         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1151                 metadata=metadata)
#    1152
#    1153         if self.width is None and self.metadata.get('width', {}):
#
# D:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, metadata)
#     607             self.metadata = {}
#     608
# --> 609         self.reload()
#     610         self._check_data()
#     611
#
# D:\Anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
#    1180         """Reload the raw data from file or URL."""
#    1181         if self.embed:
# -> 1182             super(Image,self).reload()
#    1183             if self.retina:
#    1184                 self._retina_shape()
#
# D:\Anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
#     632         """Reload the raw data from file or URL."""
#     633         if self.filename is not None:
# --> 634             with open(self.filename, self._read_flags) as f:
#     635                 self.data = f.read()
#     636         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: './spacex.jpg'

# %% [markdown]
#  | diyilan |
#  __________
#
#  |kjdh|

# %%
<img src='./git_class.jpg',width=500
# Out:
#   File "<ipython-input-1-e845062213b6>", line 1
#     <img src='./git_class.jpg',width=500
#     ^
# SyntaxError: invalid syntax
